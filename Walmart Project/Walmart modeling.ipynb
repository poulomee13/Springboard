# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas.util.testing as tm
os.getcwd()
os.chdir('/Users/susovan/Desktop/springboard doc')
import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Data Loading
df = pd.read_csv('datasets_666204_1173952_Walmart_Store_sales.csv')

# %%
#Data Organization
#os.mkdir('Walmart Sales Project')

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
values_to_remove = [1611968.17,1409727.59 ,42.31,64.88]

# %%
df_sub = df.applymap(lambda x:np.nan if x in values_to_remove else x)

# %%
df_sub
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0          NaN       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010           NaN             0        39.93       2.514
# 3         1  26-02-2010           NaN             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0          NaN       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
#Data Definition
df_sub.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df_sub.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6433 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6431 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df_sub.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.433000e+03   6435.000000  6431.000000  6435.000000
# mean     23.000000  1.046821e+06      0.069930    60.668179     3.358607
# std      12.988182  5.643922e+05      0.255049    18.447679     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.529853e+05      0.000000    47.500000     2.933000
# 50%      23.000000  9.604761e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.419912e+06      0.000000    74.950000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %%
df.isnull().values.any()
# Out:
# False

# %%
df_sub.isnull().values.any()
# Out:
# True

# %%
a=df.nunique()
a
# Out:
# Store             45
# Date             143
# Weekly_Sales    6435
# Holiday_Flag       2
# Temperature     3528
# Fuel_Price       892
# CPI             2145
# Unemployment     349
# dtype: int64

# %%
b= df_sub.nunique()
b
# Out:
# Store             45
# Date             143
# Weekly_Sales    6433
# Holiday_Flag       2
# Temperature     3526
# Fuel_Price       892
# CPI             2145
# Unemployment     349
# dtype: int64

# %%
#percent of unique values per column
pd.DataFrame(a/len(df) * 100,columns = ['percent'])
# Out:
#                  percent
# Store           0.699301
# Date            2.222222
# Weekly_Sales  100.000000
# Holiday_Flag    0.031080
# Temperature    54.825175
# Fuel_Price     13.861694
# CPI            33.333333
# Unemployment    5.423465

# %%
pd.DataFrame(b/len(df) * 100,columns = ['percent'])
# Out:
#                 percent
# Store          0.699301
# Date           2.222222
# Weekly_Sales  99.968920
# Holiday_Flag   0.031080
# Temperature   54.794095
# Fuel_Price    13.861694
# CPI           33.333333
# Unemployment   5.423465

# %%
df['Weekly_Sales'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1643690.90
# 1       1641957.44
# 2       1611968.17
# 3       1409727.59
# 4       1554806.68
#            ...
# 6430     713173.95
# 6431     733455.07
# 6432     734464.36
# 6433     718125.53
# 6434     760281.43
# Name: Weekly_Sales, Length: 6435, dtype: float64>

# %%
df_sub['Weekly_Sales'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1643690.90
# 1       1641957.44
# 2              NaN
# 3              NaN
# 4       1554806.68
#            ...
# 6430     713173.95
# 6431     733455.07
# 6432     734464.36
# 6433     718125.53
# 6434     760281.43
# Name: Weekly_Sales, Length: 6435, dtype: float64>

# %%
df['Temperature'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       42.31
# 1       38.51
# 2       39.93
# 3       46.63
# 4       46.50
#         ...
# 6430    64.88
# 6431    64.89
# 6432    54.47
# 6433    56.47
# 6434    58.85
# Name: Temperature, Length: 6435, dtype: float64>

# %%
df_sub['Temperature'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         NaN
# 1       38.51
# 2       39.93
# 3       46.63
# 4       46.50
#         ...
# 6430      NaN
# 6431    64.89
# 6432    54.47
# 6433    56.47
# 6434    58.85
# Name: Temperature, Length: 6435, dtype: float64>

# %%
nas=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)/len(df),columns = ['percent'])
pos = nas['percent'] > 0
nas[pos]
# Out:
# Empty DataFrame
# Columns: [percent]
# Index: []

# %%
nas=pd.DataFrame(df_sub.isnull().sum().sort_values(ascending=False)/len(df_sub),columns = ['percent'])
pos = nas['percent'] > 0
nas[pos]
# Out:
#                percent
# Temperature   0.000622
# Weekly_Sales  0.000311

# %%
df_sub['Temperature'].fillna((df_sub['Temperature'].bfill()), inplace=True)

# %%
df_sub
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        38.51       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010           NaN             0        39.93       2.514
# 3         1  26-02-2010           NaN             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.89       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df_sub['Weekly_Sales'].fillna((df_sub['Weekly_Sales'].ffill()), inplace=True)

# %%
df_sub
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        38.51       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1641957.44             0        39.93       2.514
# 3         1  26-02-2010    1641957.44             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.89       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df_sub.isnull().values.any()
# Out:
# False

# %%
duplicateRowsDF = df[df.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
duplicateRowsDF = df_sub[df_sub.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
_ = df.plot.hist(bins=10, alpha=0.45)

# %%
_ = df_sub.plot.hist(bins=10, alpha=0.45)

# %%
df['Store'].hist(bins=10,figsize =(10,10), color='y')
plt.xlabel('storeID')
plt.ylabel('count of stores')
# Out:
# Text(0, 0.5, 'count of stores')

# %%
df['Weekly_Sales'].hist(bins=10,figsize =(10,10), color='y')
plt.xlabel('Sales')
plt.ylabel('values')
# Out:
# Text(0, 0.5, 'values')

# %%
df_sub['Weekly_Sales'].hist(bins=10,figsize =(10,10), color='y')
plt.xlabel('Sales')
plt.ylabel('values')
# Out:
# Text(0, 0.5, 'values')

# %%
df.plot(x='Date', y='Weekly_Sales', title= "Plot between Date and Weekly_Sales",figsize =(10,10), color='g');

plt.show(True);

# %%
#monthly sales 
df_sub['month'] = pd.DatetimeIndex(df_sub['Date']).month

df_sub.plot.scatter(x='month', y='Weekly_Sales', title= "Scatter plot between Month and Weekly_Sales",figsize =(10,10), color='r');

plt.show(True);

# %%
df.plot.scatter(x='Holiday_Flag', y='Weekly_Sales', title= "Scatter plot between Holidays and Weekly_Sales",figsize =(10,10), color='r');

plt.show(True);

# %%
df_sub['Holiday_Flag'].hist(bins=10,figsize =(10,10), color='y')
plt.xlabel('Holiday_Flag')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
df['month'] = pd.DatetimeIndex(df['Date']).month
df.plot.scatter(x='month', y='Holiday_Flag', title= "Scatter plot between Month and Holidays",figsize =(10,10), color='r');

plt.show(True);

# %%
df.plot.scatter(x='Temperature', y='Weekly_Sales', title= "Scatter plot between Temperature and Weekly_Sales",figsize =(10,10), color='r');

plt.show(True);

# %%
df_sub['Temperature'].hist(bins=10,figsize =(10,10), color='y')
plt.xlabel('Temperature')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
df['Temperature'].hist(bins=10,figsize =(10,10), color='y')
plt.xlabel('Temperature')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
df['Fuel_Price'].hist(bins=10,figsize =(10,10), color='y')
plt.xlabel('Fuel_Price')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
df.plot.scatter(x='Fuel_Price', y='Weekly_Sales', title= "Scatter plot between FuelPrice and Weekly_Sales", color='r', figsize =(10,10));

plt.show(True);

# %%
df.plot(x='Store', y='CPI', title= "Plot between Store and Consumer price index",figsize =(10,10), color='g');

plt.show(True);

# %%
df.plot(y='Weekly_Sales', x='CPI', title= "Plot between CPI and Weekly_Sales",figsize =(10,10) , color='g' );

plt.show(True);

# %%
df.plot(kind='scatter', y='Store', x='CPI', title='Plot between Store and CPI', figsize =(10,10), color='r')

plt.show(True)

# %%
df['Unemployment'].hist(bins=10,figsize =(10,10), color='y')
plt.xlabel('Unemployment Rate')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
df.plot(kind='scatter', x='Store', y='Weekly_Sales', s=df.Unemployment, color='r')

# %%
df.plot.scatter(x='Unemployment', y='Weekly_Sales', title= "Scatter plot between Unemployment and Weekly_Sales",figsize =(10,10), color='r');

plt.show(True);

# %%
df_new = df[['Unemployment', 'CPI', 'Fuel_Price', 'Temperature']]
df_new
f, ax = plt.subplots(figsize=(20, 10))
df_new.boxplot(grid=False, vert=False,fontsize=25, figsize=(10,20))

# %%
#Apply outlier removal using the Interquartile range or replacement
Q1 = df_new.quantile(0.25)
Q3 = df_new.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# Unemployment     1.731000
# CPI             81.008293
# Fuel_Price       0.802000
# Temperature     27.480000
# dtype: float64

# %%
dfno = df_new[~((df_new < (Q1 - 1.5 * IQR)) |(df_new> (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df_box = dfno.boxplot(grid=False, vert=False,fontsize=15, figsize=(10,10))

# %%
print(df.shape)
print(dfno.shape)
dfno
# Out:
# (6435, 9)
# (5951, 4)
#       Unemployment         CPI  Fuel_Price  Temperature
# 0            8.106  211.096358       2.572        42.31
# 1            8.106  211.242170       2.548        38.51
# 2            8.106  211.289143       2.514        39.93
# 3            8.106  211.319643       2.561        46.63
# 4            8.106  211.350143       2.625        46.50
# ...            ...         ...         ...          ...
# 6430         8.684  192.013558       3.997        64.88
# 6431         8.667  192.170412       3.985        64.89
# 6432         8.667  192.327265       4.000        54.47
# 6433         8.667  192.330854       3.969        56.47
# 6434         8.667  192.308899       3.882        58.85
#
# [5951 rows x 4 columns]

# %%
df['Weekly_Sales'].hist(bins=10,figsize =(10,10), color='y')
plt.xlabel('Sales')
plt.ylabel('values')
# Out:
# Text(0, 0.5, 'values')

# %%
df.plot(x='Date', y='Weekly_Sales', title= "Plot between Date and Weekly_Sales",figsize =(10,10), color='g');

plt.show(True);

# %%
#monthly sales 
df['month'] = pd.DatetimeIndex(df['Date']).month

df.plot.scatter(x='month', y='Weekly_Sales', title= "Scatter plot between Date and Weekly_Sales",figsize =(10,10), color='r');

plt.show(True);

# %%
df.plot.scatter(x='Store', y='Unemployment', title= "Plot between Store and Unemployment", figsize =(10,10), color='r');
plt.xlabel('Store Number')
plt.ylabel('Unemployment Number')
plt.show()

# %%
df.plot.scatter(x='CPI', y='Unemployment', title= "Plot between Store and Unemployment", figsize =(10,10), color='r');
plt.xlabel('CPI')
plt.ylabel('Unemployment')
plt.show()

# %%
sns.set()
sns.pairplot(df_new)
plt.show()

# %%
#Calculate the correlation coefficients
#corr = df_new.corr()
#print(corr)
#corr.isna()

#corr.round(2).style.background_gradient(cmap='coolwarm')
plt.figure(figsize=(12,10))
print('Correlation between various features')
p=sns.heatmap(df_new.corr(), annot=True,cmap ='Blues')
# Out:
# Correlation between various features

# %%
corr_matrix = df_new.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
print(upper)
# Out:
#               Unemployment      CPI  Fuel_Price  Temperature
# Unemployment           NaN  0.30202    0.034684     0.101158
# CPI                    NaN      NaN    0.170642     0.176888
# Fuel_Price             NaN      NaN         NaN     0.144982
# Temperature            NaN      NaN         NaN          NaN

# %%
to_drop =[column for column in upper.columns if any(upper[column] > 0.70)]

print(to_drop)
# Out:
# []

# %%
#No categorical variable so no need to create dummy or indicator features for categorical variables
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment  month
# 0     211.096358         8.106      5
# 1     211.242170         8.106     12
# 2     211.289143         8.106      2
# 3     211.319643         8.106      2
# 4     211.350143         8.106      5
# ...          ...           ...    ...
# 6430  192.013558         8.684      9
# 6431  192.170412         8.667      5
# 6432  192.327265         8.667     12
# 6433  192.330854         8.667     10
# 6434  192.308899         8.667     10
#
# [6435 rows x 9 columns]

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year


df_new = df.drop('Date', axis=1)


df_new
# Out:
#       Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price         CPI  \
# 0         1    1643690.90             0        42.31       2.572  211.096358
# 1         1    1641957.44             1        38.51       2.548  211.242170
# 2         1    1611968.17             0        39.93       2.514  211.289143
# 3         1    1409727.59             0        46.63       2.561  211.319643
# 4         1    1554806.68             0        46.50       2.625  211.350143
# ...     ...           ...           ...          ...         ...         ...
# 6430     45     713173.95             0        64.88       3.997  192.013558
# 6431     45     733455.07             0        64.89       3.985  192.170412
# 6432     45     734464.36             0        54.47       4.000  192.327265
# 6433     45     718125.53             0        56.47       3.969  192.330854
# 6434     45     760281.43             0        58.85       3.882  192.308899
#
#       Unemployment  month  Year
# 0            8.106      5  2010
# 1            8.106     12  2010
# 2            8.106      2  2010
# 3            8.106      2  2010
# 4            8.106      5  2010
# ...            ...    ...   ...
# 6430         8.684      9  2012
# 6431         8.667      5  2012
# 6432         8.667     12  2012
# 6433         8.667     10  2012
# 6434         8.667     10  2012
#
# [6435 rows x 9 columns]

# %%
X=df_new[['Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'month', 'Year']]
y=df_new[['Weekly_Sales']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.5, random_state=1)

# %%
from sklearn import preprocessing
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
#Multivariable Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)

#coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])  

pd.DataFrame({"Feature":X_train.columns.tolist(),"Coefficients":regressor.coef_[0]})
# Out:
#         Feature  Coefficients
# 0  Holiday_Flag  11448.645282
# 1   Temperature  -1373.542047
# 2    Fuel_Price  71906.175551
# 3           CPI  -1011.257417
# 4  Unemployment -40133.856509
# 5         month  11229.787434
# 6          Year -64309.152168

# %%
print('\nIntercept of model is:',regressor.intercept_)
# Out:
# Intercept of model is: [1.30634834e+08]

# %%
y_pred = regressor.predict(X_test)
train_score = regressor.score(X_train, y_train)
test_score = regressor.score(X_test, y_test)
print('Train Score: ', regressor.score(X_train, y_train))  
print('Test Score: ', regressor.score(X_test, y_test))
# Out:
# Train Score:  0.02774336886706108
# Test Score:  0.033980289789513285

# %%
accuracy = regressor.score(X_test,y_test)
print(accuracy*100,'%')
# Out:
# 3.3980289789513285 %

# %%
#The performance of the model can be evaluated by finding the root mean squared error of the model.

# %%
from sklearn.metrics import r2_score
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r2_score:',r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 466854.81592854013
# Mean Squared Error: 305412762800.28723
# Root Mean Squared Error: 552641.6223922039
# r2_score: 0.033980289789513285

# %%
from sklearn.model_selection import cross_val_score
# storing the ten scores in an object called mse
mse= cross_val_score(regressor,X,y,scoring='neg_mean_squared_error',cv=10)
# taking the mean of mse for using as an indicator of how good the model is
mse.mean()
# Out:
# -352851266592.6913

# %%
# Saving an array containing all the coefficients
regressor_coeffs = regressor.coef_[0]
regressor_coeffs
# Out:
# array([ 11448.64528224,  -1373.5420467 ,  71906.17555066,  -1011.25741686,
#        -40133.85650935,  11229.7874336 , -64309.15216764])

# %%
feature_names = df_new.drop(['Weekly_Sales','Store'],axis=1).columns
feature_names
# Out:
# Index(['Holiday_Flag', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment',
#        'month', 'Year'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
plt.plot(range(len(regressor_coeffs)),regressor_coeffs)
plt.axhline(0, color='r', linestyle='solid')
plt.xticks(range(len(feature_names)),feature_names,rotation=50)
plt.title("Coefficients for Multiple Linear Regression")
plt.ylabel("coefficients")
plt.xlabel("features")
plt.show()

# %%
#Holiday_Flag,Fuel_Price,Unemployment,month have a considerable impact on the sale.

# %%
#RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=80, random_state=0)

# %%
X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(X, y, test_size=.5, random_state=1)
model.fit(X_train_rf, y_train_rf)
y_pred_rf = model.predict(X_test_rf)

# %%
train_scorerf = model.score(X_train_rf, y_train_rf)
test_scorerf = model.score(X_test_rf, y_test_rf)                            
print('Train Scorerf: ', model.score(X_train_rf, y_train_rf))  
print('Test Scorerf: ', model.score(X_test_rf, y_test_rf))
# Out:
# Train Scorerf:  0.8079547554687941
# Test Scorerf:  0.09804637884409217

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test_rf, y_pred_rf))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test_rf, y_pred_rf))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test_rf, y_pred_rf)))
print('r2_score:',r2_score(y_test_rf, y_pred_rf))
# Out:
# Mean Absolute Error: 395031.8709669888
# Mean Squared Error: 285157895272.06177
# Root Mean Squared Error: 534001.77459636
# r2_score: 0.09804637884409217

# %%
mse_rf= cross_val_score(model,X,y,scoring='neg_mean_squared_error',cv=10)
# taking the mean of mse for using as an indicator of how good the model is
mse_rf.mean()
# Out:
# -689615854165.7723

# %%
accuracy_rf = model.score(X_test,y_test)
print(accuracy_rf*100,'%')
# Out:
# 9.804637884409217 %

# %%
#Comparison of the models:

# %%
myLabels = [ 'Linear Regression','Random Forest']
score_test= [  test_score,test_scorerf]
score_train= [train_score,train_scorerf]
Accuracy_score = [accuracy,accuracy_rf]

score_tab_acc = pd.DataFrame(list(zip(myLabels, Accuracy_score)), 
               columns =['Algorithm', 'Model accuracy score']) 

score_tab = pd.DataFrame(list(zip(myLabels, score_train, score_test)), 
               columns =['Algorithm', 'train score', ' test score' ]) 
print(score_tab_acc)

score_tab
# Out:
#            Algorithm  Model accuracy score
# 0  Linear Regression              0.033980
# 1      Random Forest              0.098046
#            Algorithm  train score   test score
# 0  Linear Regression     0.027743     0.033980
# 1      Random Forest     0.807955     0.098046

# %%
#Applying Grid search CV for hyperparameter Tuning

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [70,80, 90, 100, 110],
    'max_features': [6, 7],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

# Create a base model
rf = RandomForestRegressor(random_state = 42)

# Instantiate the grid search model
grid_search_rf = GridSearchCV(estimator = rf, param_grid = param_grid, 
                         cv = 3, n_jobs = -1, verbose = 2, return_train_score=True)

# %%
grid_search_rf.fit(X,y)
# Out:
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   44.2s
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 357 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 640 tasks      | elapsed: 17.3min
# [Parallel(n_jobs=-1)]: Done 1005 tasks      | elapsed: 27.2min
# [Parallel(n_jobs=-1)]: Done 1080 out of 1080 | elapsed: 29.4min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=42,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'bootstrap': [True],
#                          'max_depth': [70, 80, 90, 100, 110],
#                          'max_features': [6, 7], 'min_samples_leaf': [3, 4, 5],
#                          'min_samples_split': [8, 10, 12],
#                          'n_estimators': [100, 200, 300, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=2)

# %%
print("Best Score:" + str(grid_search_rf.best_score_))
print("Best Parameters: " + str(grid_search_rf.best_params_))
# Out:
# Best Score:-1.9844251646869842
# Best Parameters: {'bootstrap': True, 'max_depth': 70, 'max_features': 6, 'min_samples_leaf': 5, 'min_samples_split': 12, 'n_estimators': 200}

# %%
#Fitting the Random forest model with the optimal hyperparameters

# %%
rf = RandomForestRegressor(bootstrap=True, criterion='mse',
            max_depth=70, max_features=6, max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=5, min_samples_split=12,
            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
            oob_score=False, random_state=42, verbose=0, warm_start=False)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print('Mean Squared Error:', metrics.mean_squared_error(y_test_rf, y_pred_rf))
# Out:
# Mean Squared Error: 247818855552.0846

# %%
#Feature importances:

features = X
importances = list(rf.feature_importances_)
imp=np.sort(importances)
tab=pd.DataFrame(list(zip(X,imp)),columns =['Features', 'Importance scores']) 
print(tab)
# Out:
#        Features  Importance scores
# 0  Holiday_Flag           0.006836
# 1   Temperature           0.021704
# 2    Fuel_Price           0.065021
# 3           CPI           0.124421
# 4  Unemployment           0.165380
# 5         month           0.287859
# 6          Year           0.328779
