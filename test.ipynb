# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas.util.testing as tm
os.getcwd()
os.chdir('/Users/susovan/Desktop/springboard doc/capstone2')

# %%
#Data Loading
df = pd.read_csv('test.csv')

# %%
df.head(20)
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000004  P00128942      M  46-50           7             B
# 1   1000009  P00113442      M  26-35          17             C
# 2   1000010  P00288442      F  36-45           1             B
# 3   1000010  P00145342      F  36-45           1             B
# 4   1000011  P00053842      F  26-35           1             C
# 5   1000013  P00350442      M  46-50           1             C
# 6   1000013  P00155442      M  46-50           1             C
# 7   1000013   P0094542      M  46-50           1             C
# 8   1000015  P00161842      M  26-35           7             A
# 9   1000022  P00067942      M  18-25          15             A
# 10  1000026  P00046742      M  26-35           7             B
# 11  1000026  P00040042      M  26-35           7             B
# 12  1000026  P00196542      M  26-35           7             B
# 13  1000026  P00004542      M  26-35           7             B
# 14  1000028  P00159542      F  26-35           1             C
# 15  1000029  P00111542      M  36-45           7             C
# 16  1000033  P00121042      M  46-50           3             A
# 17  1000033  P00344442      M  46-50           3             A
# 18  1000034  P00265242      F  18-25           0             A
# 19  1000035   P0096642      M  46-50           1             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               1                   1
# 1                           0               0                   3
# 2                          4+               1                   5
# 3                          4+               1                   4
# 4                           1               0                   4
# 5                           3               1                   2
# 6                           3               1                   1
# 7                           3               1                   2
# 8                           1               0                  10
# 9                          4+               0                   5
# 10                          2               1                   1
# 11                          2               1                   5
# 12                          2               1                   5
# 13                          2               1                   5
# 14                          2               1                  10
# 15                          1               0                   2
# 16                          1               1                  15
# 17                          1               1                   5
# 18                          0               0                   5
# 19                         4+               1                   2
#
#     Product_Category_2  Product_Category_3
# 0                 11.0                 NaN
# 1                  5.0                 NaN
# 2                 14.0                 NaN
# 3                  9.0                 NaN
# 4                  5.0                12.0
# 5                  3.0                15.0
# 6                 11.0                15.0
# 7                  4.0                 9.0
# 8                 13.0                16.0
# 9                 14.0                 NaN
# 10                 2.0                15.0
# 11                 NaN                 NaN
# 12                 8.0                14.0
# 13                 8.0                 NaN
# 14                15.0                16.0
# 15                17.0                 NaN
# 16                 NaN                 NaN
# 17                 8.0                14.0
# 18                 8.0                 NaN
# 19                 3.0                 4.0

# %%
#Data Definition
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3'],
#       dtype='object')

# %%
df.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233599 entries, 0 to 233598
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     233599 non-null  int64
#  1   Product_ID                  233599 non-null  object
#  2   Gender                      233599 non-null  object
#  3   Age                         233599 non-null  object
#  4   Occupation                  233599 non-null  int64
#  5   City_Category               233599 non-null  object
#  6   Stay_In_Current_City_Years  233599 non-null  object
#  7   Marital_Status              233599 non-null  int64
#  8   Product_Category_1          233599 non-null  int64
#  9   Product_Category_2          161255 non-null  float64
#  10  Product_Category_3          71037 non-null   float64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 19.6+ MB

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  2.335990e+05  233599.000000   233599.000000       233599.000000
# mean   1.003029e+06       8.085407        0.410070            5.276542
# std    1.726505e+03       6.521146        0.491847            3.736380
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001527e+06       2.000000        0.000000            1.000000
# 50%    1.003070e+06       7.000000        0.000000            5.000000
# 75%    1.004477e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3
# count       161255.000000        71037.000000
# mean             9.849586           12.669454
# std              5.094943            4.125944
# min              2.000000            3.000000
# 25%              5.000000            9.000000
# 50%              9.000000           14.000000
# 75%             15.000000           16.000000
# max             18.000000           18.000000

# %%
df.isnull().values.any()
# Out:
# True

# %%
a=df.nunique()
a
# Out:
# User_ID                       5891
# Product_ID                    3491
# Gender                           2
# Age                              7
# Occupation                      21
# City_Category                    3
# Stay_In_Current_City_Years       5
# Marital_Status                   2
# Product_Category_1              18
# Product_Category_2              17
# Product_Category_3              15
# dtype: int64

# %%
#percent of unique values per column
pd.DataFrame(a/len(df) * 100,columns = ['percent'])
# Out:
#                              percent
# User_ID                     2.521843
# Product_ID                  1.494441
# Gender                      0.000856
# Age                         0.002997
# Occupation                  0.008990
# City_Category               0.001284
# Stay_In_Current_City_Years  0.002140
# Marital_Status              0.000856
# Product_Category_1          0.007706
# Product_Category_2          0.007277
# Product_Category_3          0.006421

# %%
df['Product_Category_1'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          1
# 1          3
# 2          5
# 3          4
# 4          4
#           ..
# 233594     8
# 233595     5
# 233596     1
# 233597    10
# 233598     4
# Name: Product_Category_1, Length: 233599, dtype: int64>

# %%
df['Product_Category_2'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         11.0
# 1          5.0
# 2         14.0
# 3          9.0
# 4          5.0
#           ...
# 233594     NaN
# 233595     8.0
# 233596     5.0
# 233597    16.0
# 233598     5.0
# Name: Product_Category_2, Length: 233599, dtype: float64>

# %%
df['Product_Category_3'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4         12.0
#           ...
# 233594     NaN
# 233595     NaN
# 233596    12.0
# 233597     NaN
# 233598     NaN
# Name: Product_Category_3, Length: 233599, dtype: float64>

# %%
nas=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)/len(df),columns = ['percent'])
pos = nas['percent'] > 0
nas[pos]
# Out:
#                      percent
# Product_Category_3  0.695902
# Product_Category_2  0.309693

# %%
df['Product_Category_2'].fillna(0, inplace = True)

# %%
df['Product_Category_3'].fillna(0, inplace = True)

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.head(20)
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000004  P00128942      M  46-50           7             B
# 1   1000009  P00113442      M  26-35          17             C
# 2   1000010  P00288442      F  36-45           1             B
# 3   1000010  P00145342      F  36-45           1             B
# 4   1000011  P00053842      F  26-35           1             C
# 5   1000013  P00350442      M  46-50           1             C
# 6   1000013  P00155442      M  46-50           1             C
# 7   1000013   P0094542      M  46-50           1             C
# 8   1000015  P00161842      M  26-35           7             A
# 9   1000022  P00067942      M  18-25          15             A
# 10  1000026  P00046742      M  26-35           7             B
# 11  1000026  P00040042      M  26-35           7             B
# 12  1000026  P00196542      M  26-35           7             B
# 13  1000026  P00004542      M  26-35           7             B
# 14  1000028  P00159542      F  26-35           1             C
# 15  1000029  P00111542      M  36-45           7             C
# 16  1000033  P00121042      M  46-50           3             A
# 17  1000033  P00344442      M  46-50           3             A
# 18  1000034  P00265242      F  18-25           0             A
# 19  1000035   P0096642      M  46-50           1             C
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                           2               1                   1
# 1                           0               0                   3
# 2                          4+               1                   5
# 3                          4+               1                   4
# 4                           1               0                   4
# 5                           3               1                   2
# 6                           3               1                   1
# 7                           3               1                   2
# 8                           1               0                  10
# 9                          4+               0                   5
# 10                          2               1                   1
# 11                          2               1                   5
# 12                          2               1                   5
# 13                          2               1                   5
# 14                          2               1                  10
# 15                          1               0                   2
# 16                          1               1                  15
# 17                          1               1                   5
# 18                          0               0                   5
# 19                         4+               1                   2
#
#     Product_Category_2  Product_Category_3
# 0                 11.0                 0.0
# 1                  5.0                 0.0
# 2                 14.0                 0.0
# 3                  9.0                 0.0
# 4                  5.0                12.0
# 5                  3.0                15.0
# 6                 11.0                15.0
# 7                  4.0                 9.0
# 8                 13.0                16.0
# 9                 14.0                 0.0
# 10                 2.0                15.0
# 11                 0.0                 0.0
# 12                 8.0                14.0
# 13                 8.0                 0.0
# 14                15.0                16.0
# 15                17.0                 0.0
# 16                 0.0                 0.0
# 17                 8.0                14.0
# 18                 8.0                 0.0
# 19                 3.0                 4.0

# %%
duplicateRowsDF = df[df.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [User_ID, Product_ID, Gender, Age, Occupation, City_Category, Stay_In_Current_City_Years, Marital_Status, Product_Category_1, Product_Category_2, Product_Category_3]
# Index: []

# %%
hx = df.plot.hist(bins=10, alpha=0.45)

# %%
f, ax = plt.subplots(figsize=(20, 10))
df.boxplot(grid=False, vert=False,fontsize=25, figsize=(10,20))

# %%
df['Product_Category_1'].hist(bins=10,figsize =(10,10))

# %%
df['Product_Category_2'].hist(bins=10,figsize =(10,10))

# %%
df['Product_Category_3'].hist(bins=10,figsize =(10,10))

# %%
sns.pairplot(df)
plt.show()

# %%
#Calculate the correlation coefficients
corr = df.corr()
print(corr)
corr.isna()

corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023988        0.019883            0.006428
# Occupation         -0.023988    1.000000        0.021872           -0.010465
# Marital_Status      0.019883    0.021872        1.000000            0.018860
# Product_Category_1  0.006428   -0.010465        0.018860            1.000000
# Product_Category_2  0.003590    0.009089        0.008597           -0.035237
# Product_Category_3 -0.000533    0.013456       -0.006879           -0.389516
#
#                     Product_Category_2  Product_Category_3
# User_ID                       0.003590           -0.000533
# Occupation                    0.009089            0.013456
# Marital_Status                0.008597           -0.006879
# Product_Category_1           -0.035237           -0.389516
# Product_Category_2            1.000000            0.087280
# Product_Category_3            0.087280            1.000000
# <style  type="text/css" >
#     #T_7d439162_c607_11ea_a33b_f45c89b69263row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row0_col2 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row0_col3 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row0_col4 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row0_col5 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row1_col2 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row1_col3 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row1_col4 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row1_col5 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row2_col0 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row2_col1 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row2_col3 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row2_col4 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row2_col5 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row3_col0 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row3_col1 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row3_col2 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row3_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row4_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row4_col1 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row4_col2 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row4_col3 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row4_col5 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row5_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row5_col1 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row5_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row5_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row5_col4 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_7d439162_c607_11ea_a33b_f45c89b69263row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_7d439162_c607_11ea_a33b_f45c89b69263" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >User_ID</th>        <th class="col_heading level0 col1" >Occupation</th>        <th class="col_heading level0 col2" >Marital_Status</th>        <th class="col_heading level0 col3" >Product_Category_1</th>        <th class="col_heading level0 col4" >Product_Category_2</th>        <th class="col_heading level0 col5" >Product_Category_3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7d439162_c607_11ea_a33b_f45c89b69263level0_row0" class="row_heading level0 row0" >User_ID</th>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row0_col1" class="data row0 col1" >-0.020000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row0_col2" class="data row0 col2" >0.020000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row0_col3" class="data row0 col3" >0.010000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row0_col4" class="data row0 col4" >0.000000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row0_col5" class="data row0 col5" >-0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_7d439162_c607_11ea_a33b_f45c89b69263level0_row1" class="row_heading level0 row1" >Occupation</th>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row1_col0" class="data row1 col0" >-0.020000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row1_col2" class="data row1 col2" >0.020000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row1_col3" class="data row1 col3" >-0.010000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row1_col4" class="data row1 col4" >0.010000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row1_col5" class="data row1 col5" >0.010000</td>
#             </tr>
#             <tr>
#                         <th id="T_7d439162_c607_11ea_a33b_f45c89b69263level0_row2" class="row_heading level0 row2" >Marital_Status</th>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row2_col0" class="data row2 col0" >0.020000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row2_col1" class="data row2 col1" >0.020000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row2_col3" class="data row2 col3" >0.020000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row2_col4" class="data row2 col4" >0.010000</td>
#                         <td id="T_7d439162_c607_11ea_a33b_f45c89b69263row2_col5" class="data row2 col5" >-0.010000</td>
#             </tr>

# %%
data = df[['Product_Category_1', 'Product_Category_2', 'Product_Category_3']]
corr_matrix = data.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
print(upper)
# Out:
#                     Product_Category_1  Product_Category_2  Product_Category_3
# Product_Category_1                 NaN            0.035237            0.389516
# Product_Category_2                 NaN                 NaN            0.087280
# Product_Category_3                 NaN                 NaN                 NaN

# %%
to_drop =[column for column in upper.columns if any(upper[column] > 0.95)]

print(to_drop)
# Out:
# []
